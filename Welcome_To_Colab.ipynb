# %%
import pandas as pd

# Step 1: Read the uploaded file
df = pd.read_csv('/content/students.csv')

# Step 2: Remove rows with missing (empty) values
df_clean = df.dropna()

# Step 3: Save the cleaned data to a new file
df_clean.to_csv('/content/students_cleaned.csv', index=False)

# Step 4: Show the cleaned data
df_clean
# Out:
#    Name   Age  Marks
# 0   Ali  20.0   80.0
# 3  Riya  22.0   85.0
